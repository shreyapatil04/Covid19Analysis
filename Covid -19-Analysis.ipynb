# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('covid.xlsx')

# %%
df
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     0               Andaman and Nicobar Islands      23      4980     4875
# 1     1                            Andhra Pradesh    2544    849016   875243
# 2     2                         Arunachal Pradesh      66     16772    16850
# 3     3                                     Assam    3014    216590   212515
# 4     4                                     Bihar    4178    250256   245234
# 5     5                                Chandigarh     241     20925    19727
# 6     6                              Chhattisgarh    8697    228361   207770
# 7     7  Dadra and Nagar Haveli and Daman and Diu       0      3382     3376
# 8     8                                     Delhi    3468    630200   610504
# 9     9                                       Goa     633     51284    49934
# 10   10                                   Gujarat    7282    259216   239771
# 11   11                                   Haryana    2510    284955   259495
# 12   12                          Himachal Pradesh     971     56452    54522
# 13   13                         Jammu and Kashmir    2011    122538   118617
# 14   14                                 Jharkhand    1468    118177   114015
# 15   15                                 Karnataka    9688    927559   905751
# 16   16                                    Kerala   64378    811148   743467
# 17   17                                    Ladakh       0      9618     9249
# 18   18                               Lakshadweep       0         0        0
# 19   19                            Madhya Pradesh    7823    248597   237063
# 20   20                               Maharashtra   45313   1593110  1406031
# 21   21                                   Manipur     490     28696    27805
# 22   22                                 Meghalaya     155     13981    13394
# 23   23                                   Mizoram     490      4293     4194
# 24   24                                  Nagaland     116     11978    11778
# 25   25                                    Odisha     633    328602   324926
# 26   26                                Puducherry     315     40891    39675
# 27   27                                    Punjab    2933    130603   106055
# 28   28                                 Rajasthan    6720    308936   303658
# 29   29                                    Sikkim     351      5988     5508
# 30   30                                Tamil Nadu    7184    826281   808673
# 31   31                                 Telangana    4146    298008   293328
# 32   32                                   Tripura      50     33307    32850
# 33   33                               Uttarakhand     311     61481    58875
# 34   34                             Uttar Pradesh   11134    937181   873424
# 35   35                               West Bengal    7881    560790   542887
#
#     death  new_active  new_positive  new_cured  new_death  state_code
# 0      62          17          4963       4884         62          35
# 1    7120          85        850307     875456       7131          28
# 2      56          31         16777      16858         56          12
# 3    1091         292        216835     212640       1094          18
# 4    1375        2509        250592     250439       1380          10
# 5     327         259         20934      19756        327           4
# 6    2652        2902        228902     208780       2665          22
# 7       2           4          3382       3376          2          26
# 8   10678         334        630506     611641      10981           7
# 9     749         143         51361      50084        751          30
# 10   4413        3054        259468     240009       4422          24
# 11   2950        2547        285169     259696       2956           6
# 12    959         874         56521      54621        961           2
# 13   1910        1788        122651     118972       1911           1
# 14   1070         936        118205     114049       1074          20
# 15  12140        9383        928055     906548      12144          29
# 16   3302       63547        814258     747398       3322          32
# 17    127           0          9618       9249        127          37
# 18      0           0             0          0          0          31
# 19   3711        7651        249082     237713       3718          23
# 20  41869        3548       1594098    1406750      50101          27
# 21    365         477         28693      27851        365          14
# 22    144         131         13337        145         13          17
# 23     10          10          4301       4194         10          15
# 24     84         108         11987      11795         84          13
# 25   1893        1943        328106     324461       1894          21
# 26    683         304         40877      39735        683          34
# 27   5445        2858        130225     106902       5447           3
# 28   5442        3136        304140       2763          8           8
# 29    122         322          5969       5538        122          11
# 30  12227        6877        826493     807744      12228          33
# 31   1634         847        298091     293766       1637          36
# 32    391          49         33309      32872        391          16
# 33   1043         375         61541      58945       1045           5
# 34  10854        5936        937654     874216      10873           9
# 35   9041        5631        561321     543826       9057          19

# %% [markdown]
# ### DataUnderstanding

# %%
df.shape
# Out:
# (36, 11)

# %%
df.isnull().sum()
# Out:
# sno             0
# state_name      0
# active          0
# positive        0
# cured           0
# death           0
# new_active      0
# new_positive    0
# new_cured       0
# new_death       0
# state_code      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sno           36 non-null     int64
#  1   state_name    36 non-null     object
#  2   active        36 non-null     int64
#  3   positive      36 non-null     int64
#  4   cured         36 non-null     int64
#  5   death         36 non-null     int64
#  6   new_active    36 non-null     int64
#  7   new_positive  36 non-null     int64
#  8   new_cured     36 non-null     int64
#  9   new_death     36 non-null     int64
#  10  state_code    36 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 3.2+ KB

# %%
df.describe()
# Out:
#              sno        active      positive         cured         death  \
# count  36.000000     36.000000  3.600000e+01  3.600000e+01     36.000000
# mean   17.500000   5756.027778  2.859487e+05  2.716955e+05   4053.916667
# std    10.535654  12713.986479  3.715155e+05  3.467424e+05   7481.963571
# min     0.000000      0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%     8.750000    293.500000  1.988675e+04  1.900775e+04    281.250000
# 50%    17.500000   1739.500000  1.265705e+05  1.163160e+05   1233.000000
# 75%    26.250000   6836.000000  3.138525e+05  3.089750e+05   4670.250000
# max    35.000000  64378.000000  1.593110e+06  1.406031e+06  41869.000000
#
#          new_active  new_positive     new_cured     new_death  state_code
# count     36.000000  3.600000e+01  3.600000e+01     36.000000   36.000000
# mean    3580.777778  2.860480e+05  2.634353e+05   4140.055556   18.833333
# std    10567.856861  3.718703e+05  3.501288e+05   8733.081632   10.929645
# min        0.000000  0.000000e+00  0.000000e+00      0.000000    1.000000
# 25%      125.250000  1.989475e+04  1.559225e+04    125.750000    9.750000
# 50%      662.000000  1.264380e+05  1.104755e+05   1084.000000   18.500000
# 75%     2940.000000  3.101315e+05  3.014398e+05   3894.000000   28.250000
# max    63547.000000  1.594098e+06  1.406750e+06  50101.000000   37.000000

# %%
df.keys()
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
df.nunique()
# Out:
# sno             36
# state_name      36
# active          32
# positive        36
# cured           36
# death           36
# new_active      35
# new_positive    36
# new_cured       36
# new_death       36
# state_code      36
# dtype: int64

# %%
df.tail()
# Out:
#     sno     state_name  active  positive   cured  death  new_active  \
# 31   31      Telangana    4146    298008  293328   1634         847
# 32   32        Tripura      50     33307   32850    391          49
# 33   33    Uttarakhand     311     61481   58875   1043         375
# 34   34  Uttar Pradesh   11134    937181  873424  10854        5936
# 35   35    West Bengal    7881    560790  542887   9041        5631
#
#     new_positive  new_cured  new_death  state_code
# 31        298091     293766       1637          36
# 32         33309      32872        391          16
# 33         61541      58945       1045           5
# 34        937654     874216      10873           9
# 35        561321     543826       9057          19

# %%
df=df.iloc[:36]

# %%
df
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     0               Andaman and Nicobar Islands      23      4980     4875
# 1     1                            Andhra Pradesh    2544    849016   875243
# 2     2                         Arunachal Pradesh      66     16772    16850
# 3     3                                     Assam    3014    216590   212515
# 4     4                                     Bihar    4178    250256   245234
# 5     5                                Chandigarh     241     20925    19727
# 6     6                              Chhattisgarh    8697    228361   207770
# 7     7  Dadra and Nagar Haveli and Daman and Diu       0      3382     3376
# 8     8                                     Delhi    3468    630200   610504
# 9     9                                       Goa     633     51284    49934
# 10   10                                   Gujarat    7282    259216   239771
# 11   11                                   Haryana    2510    284955   259495
# 12   12                          Himachal Pradesh     971     56452    54522
# 13   13                         Jammu and Kashmir    2011    122538   118617
# 14   14                                 Jharkhand    1468    118177   114015
# 15   15                                 Karnataka    9688    927559   905751
# 16   16                                    Kerala   64378    811148   743467
# 17   17                                    Ladakh       0      9618     9249
# 18   18                               Lakshadweep       0         0        0
# 19   19                            Madhya Pradesh    7823    248597   237063
# 20   20                               Maharashtra   45313   1593110  1406031
# 21   21                                   Manipur     490     28696    27805
# 22   22                                 Meghalaya     155     13981    13394
# 23   23                                   Mizoram     490      4293     4194
# 24   24                                  Nagaland     116     11978    11778
# 25   25                                    Odisha     633    328602   324926
# 26   26                                Puducherry     315     40891    39675
# 27   27                                    Punjab    2933    130603   106055
# 28   28                                 Rajasthan    6720    308936   303658
# 29   29                                    Sikkim     351      5988     5508
# 30   30                                Tamil Nadu    7184    826281   808673
# 31   31                                 Telangana    4146    298008   293328
# 32   32                                   Tripura      50     33307    32850
# 33   33                               Uttarakhand     311     61481    58875
# 34   34                             Uttar Pradesh   11134    937181   873424
# 35   35                               West Bengal    7881    560790   542887
#
#     death  new_active  new_positive  new_cured  new_death  state_code
# 0      62          17          4963       4884         62          35
# 1    7120          85        850307     875456       7131          28
# 2      56          31         16777      16858         56          12
# 3    1091         292        216835     212640       1094          18
# 4    1375        2509        250592     250439       1380          10
# 5     327         259         20934      19756        327           4
# 6    2652        2902        228902     208780       2665          22
# 7       2           4          3382       3376          2          26
# 8   10678         334        630506     611641      10981           7
# 9     749         143         51361      50084        751          30
# 10   4413        3054        259468     240009       4422          24
# 11   2950        2547        285169     259696       2956           6
# 12    959         874         56521      54621        961           2
# 13   1910        1788        122651     118972       1911           1
# 14   1070         936        118205     114049       1074          20
# 15  12140        9383        928055     906548      12144          29
# 16   3302       63547        814258     747398       3322          32
# 17    127           0          9618       9249        127          37
# 18      0           0             0          0          0          31
# 19   3711        7651        249082     237713       3718          23
# 20  41869        3548       1594098    1406750      50101          27
# 21    365         477         28693      27851        365          14
# 22    144         131         13337        145         13          17
# 23     10          10          4301       4194         10          15
# 24     84         108         11987      11795         84          13
# 25   1893        1943        328106     324461       1894          21
# 26    683         304         40877      39735        683          34
# 27   5445        2858        130225     106902       5447           3
# 28   5442        3136        304140       2763          8           8
# 29    122         322          5969       5538        122          11
# 30  12227        6877        826493     807744      12228          33
# 31   1634         847        298091     293766       1637          36
# 32    391          49         33309      32872        391          16
# 33   1043         375         61541      58945       1045           5
# 34  10854        5936        937654     874216      10873           9
# 35   9041        5631        561321     543826       9057          19

# %%
df['active'].sum(axis = 0)
# Out:
# 207217

# %%
df['positive'].sum(axis = 0)
# Out:
# 10294152

# %%
df['cured'].sum(axis = 0)
# Out:
# 9781039

# %%
df['death'].sum(axis = 0)
# Out:
# 145941

# %%
df['new_active'].sum(axis = 0)
# Out:
# 128908

# %%
df['new_positive'].sum(axis = 0)
# Out:
# 10297728

# %%
df['new_cured'].sum(axis = 0)
# Out:
# 9483672

# %%
df['new_death'].sum(axis = 0)
# Out:
# 149042

# %% [markdown]
# ### Data Visualization

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.pairplot(data=df)

# %%
cases_df=df.sum()

# %%
cases_df
# Out:
# sno                                                           630
# state_name      Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                     207217
# positive                                                 10294152
# cured                                                     9781039
# death                                                      145941
# new_active                                                 128908
# new_positive                                             10297728
# new_cured                                                 9483672
# new_death                                                  149042
# state_code                                                    678
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)

# %%
cases_df
# Out:
# active            207217
# positive        10294152
# cured            9781039
# death             145941
# new_active        128908
# new_positive    10297728
# new_cured        9483672
# new_death         149042
# dtype: object

# %%
my_data = [222526,10466595,10092909,151160]
my_labels = 'Active','Positive','Cured','Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()

# %%
my_data = [216558,10479179,10111294,151327]
my_labels = 'New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()

# %%
my_data = [222526,10466595,10092909,151160,216558,10479179,10111294,151327]
my_labels = 'Active','Positive','Cured','Death','New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,0,0,0,0,1.5)
my_colors = ['gray','navajowhite','blanchedalmond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()

# %%
plt.rcParams['figure.figsize']=(13,8)

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their active level of cases.
# Kerela has a higher active cases compared to other states

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()

# %%
df.columns
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='teal',data=df);
# The visualization below shows us that high number of active cases are found in kerala followed by maharashtra

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);

# %%
df.columns
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
df.drop(['sno','state_code'],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#                     state_name  active  positive   cured  death  new_active  \
# 0  Andaman and Nicobar Islands      23      4980    4875     62          17
# 1               Andhra Pradesh    2544    849016  875243   7120          85
# 2            Arunachal Pradesh      66     16772   16850     56          31
# 3                        Assam    3014    216590  212515   1091         292
# 4                        Bihar    4178    250256  245234   1375        2509
#
#    new_positive  new_cured  new_death
# 0          4963       4884         62
# 1        850307     875456       7131
# 2         16777      16858         56
# 3        216835     212640       1094
# 4        250592     250439       1380

# %%
df=df.set_index('state_name')

# %%
df.head(5)
# Out:
#                              active  positive   cured  death  new_active  \
# state_name
# Andaman and Nicobar Islands      23      4980    4875     62          17
# Andhra Pradesh                 2544    849016  875243   7120          85
# Arunachal Pradesh                66     16772   16850     56          31
# Assam                          3014    216590  212515   1091         292
# Bihar                          4178    250256  245234   1375        2509
#
#                              new_positive  new_cured  new_death
# state_name
# Andaman and Nicobar Islands          4963       4884         62
# Andhra Pradesh                     850307     875456       7131
# Arunachal Pradesh                   16777      16858         56
# Assam                              216835     212640       1094
# Bihar                              250592     250439       1380

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Out:
# <Axes: ylabel='state_name'>

# %%
df1=df[['cured', 'death']] 
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# Out:
# <Axes: ylabel='state_name'>

# %%
df2=df[['positive', 'death']] 
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# Out:
# <Axes: ylabel='state_name'>

# %%
df3=df[['death', 'cured']] 
df3.plot.barh(color={"death": "red", "cured": "grey"},figsize=(13,8))
# Out:
# <Axes: ylabel='state_name'>

# %%
df4=df[['active', 'death']] 
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# Out:
# <Axes: ylabel='state_name'>

# %% [markdown]
# ## Thank You!
